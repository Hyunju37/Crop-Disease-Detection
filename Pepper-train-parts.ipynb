# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xP6hx51zkcF0mpjcZ3ca")
project = rf.workspace("capstone-qhqkt").project("pepper-parts")
dataset = project.version(2).download("yolov5")

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16078, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 16078 (delta 6), reused 9 (delta 1), pack-reused 16056
# Receiving objects: 100% (16078/16078), 14.72 MiB | 7.84 MiB/s, done.
# Resolving deltas: 100% (11038/11038), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
import torch
torch.cuda.device_count()
# Out:
# 1

# %%
import os
import json
import random
from pathlib import Path
from PIL import Image
from shutil import copy2

# %%
torch.cuda.empty_cache()

# %%
#에폭 30짜리가 더 나았음

# %%
# !python train.py --img 640 --batch 16 --epochs 40 --data "/content/yolov5/Pepper-parts-1/data.yaml" --weights yolov5l.pt --cache ram
# Out:
# 2023-11-28 09:25:44.493121: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 09:25:44.493170: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 09:25:44.493196: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --source /content/sample
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/sample, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46119048 parameters, 0 gradients, 107.7 GFLOPs
# image 1/7 /content/sample/kdef.jpg: 544x640 2 a7_peppers, 41.8ms
# image 2/7 /content/sample/pepperleaf0.jpg: 384x640 (no detections), 45.5ms
# image 3/7 /content/sample/pepperleaf1.jpg: 480x640 (no detections), 43.0ms
# ...

# %%
# !zip -r /content/yolov5/runs/train/exp.zip /content/yolov5/runs/train/exp

# %%
from google.colab import files
files.download("/content/yolov5/runs/train/exp.zip")

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --source /content/sample
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/sample, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46119048 parameters, 0 gradients, 107.7 GFLOPs
# image 1/7 /content/sample/kdef.jpg: 544x640 1 a7_pepper, 41.3ms
# image 2/7 /content/sample/pepperleaf0.jpg: 384x640 (no detections), 42.7ms
# image 3/7 /content/sample/pepperleaf1.jpg: 480x640 (no detections), 42.1ms
# ...

# %% [markdown]
# 추가한 데이터셋으로 다시

# %%
pwd
# Out:
# '/content/yolov5'

# %%
# !python train.py --img 640 --batch 16 --epochs 40 --data "Pepper-parts-2/data.yaml" --weights yolov5l.pt --cache ram
