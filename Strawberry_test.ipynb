# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xP6hx51zkcF0mpjcZ3ca")
project = rf.workspace("capstone-qhqkt").project("strawberry-parts-d9fnc")
dataset = project.version(1).download("yolov5")

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16078, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 16078 (delta 6), reused 9 (delta 1), pack-reused 16056
# Receiving objects: 100% (16078/16078), 14.64 MiB | 11.05 MiB/s, done.
# Resolving deltas: 100% (11038/11038), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
import os
import json
import random
from pathlib import Path
from PIL import Image
from shutil import copy2

# %%
# !python train.py --img 640 --batch 16 --epochs 40 --data "Strawberry-parts-1/data.yaml" --weights yolov5m.pt --cache ram
# Out:
# 2023-11-28 15:02:49.331986: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 15:02:49.332049: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 15:02:49.332081: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5m.pt, cfg=, data=Strawberry-parts-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=40, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 4.03MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m.pt to yolov5m.pt...
# 100% 40.8M/40.8M [00:00<00:00, 66.1MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     24246  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model summary: 291 layers, 20871318 parameters, 20871318 gradients, 48.2 GFLOPs
#
# Transferred 475/481 items from yolov5m.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.0005), 82 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov5/Strawberry-parts-1/train/labels... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<00:00, 7057.44it/s]
# train: New cache created: /content/yolov5/Strawberry-parts-1/train/labels.cache
# train: Caching images (0.7GB ram): 100% 630/630 [00:00<00:00, 1002.52it/s]
# val: Scanning /content/yolov5/Strawberry-parts-1/valid/labels... 152 images, 0 backgrounds, 0 corrupt: 100% 152/152 [00:00<00:00, 1983.75it/s]
# val: New cache created: /content/yolov5/Strawberry-parts-1/valid/labels.cache
# val: Caching images (0.2GB ram): 100% 152/152 [00:00<00:00, 586.23it/s]
#
# AutoAnchor: 4.71 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/exp
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/39      6.35G    0.09184    0.03012          0         15        640: 100% 40/40 [00:10<00:00,  3.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:02<00:00,  1.83it/s]
#                    all        152        236      0.228      0.136     0.0817     0.0218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/39      7.28G    0.07294    0.02683          0         15        640: 100% 40/40 [00:06<00:00,  6.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.71it/s]
#                    all        152        236      0.394      0.284      0.258     0.0979
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/39       7.3G    0.06786    0.02438          0          9        640: 100% 40/40 [00:05<00:00,  6.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.89it/s]
#                    all        152        236      0.549      0.411      0.403      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/39       7.3G    0.06178    0.02136          0         13        640: 100% 40/40 [00:05<00:00,  6.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.13it/s]
#                    all        152        236       0.75      0.479        0.5      0.199
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/39       7.3G    0.05783    0.02029          0         10        640: 100% 40/40 [00:05<00:00,  6.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.11it/s]
#                    all        152        236      0.725        0.5      0.511      0.194
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/39       7.3G    0.05379    0.02083          0         19        640: 100% 40/40 [00:05<00:00,  6.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.14it/s]
#                    all        152        236      0.697      0.566      0.574      0.259
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/39       7.3G    0.05117    0.02115          0         20        640: 100% 40/40 [00:05<00:00,  6.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.28it/s]
#                    all        152        236      0.592      0.461      0.419      0.147
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/39       7.3G    0.04846    0.01981          0         13        640: 100% 40/40 [00:05<00:00,  6.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.36it/s]
#                    all        152        236      0.747      0.426      0.435      0.156
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/39       7.3G    0.04756    0.01899          0         14        640: 100% 40/40 [00:05<00:00,  6.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.21it/s]
#                    all        152        236      0.798      0.458      0.525       0.23
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/39       7.3G    0.04641    0.01965          0         14        640: 100% 40/40 [00:05<00:00,  6.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.33it/s]
#                    all        152        236      0.768      0.559      0.604      0.269
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/39       7.3G    0.04617    0.01885          0         14        640: 100% 40/40 [00:05<00:00,  6.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.26it/s]
#                    all        152        236      0.816      0.538      0.598       0.28
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/39       7.3G    0.04466    0.01756          0         13        640: 100% 40/40 [00:05<00:00,  6.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.34it/s]
#                    all        152        236      0.724      0.523      0.542      0.218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/39       7.3G     0.0438    0.01834          0         15        640: 100% 40/40 [00:05<00:00,  6.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.09it/s]
#                    all        152        236      0.791      0.561      0.617      0.273
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/39       7.3G    0.04267    0.01846          0         17        640: 100% 40/40 [00:05<00:00,  6.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.92it/s]
#                    all        152        236      0.832      0.568      0.628        0.3
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/39       7.3G    0.04081    0.01731          0         16        640: 100% 40/40 [00:05<00:00,  6.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.94it/s]
#                    all        152        236      0.805      0.547        0.6      0.271
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/
00:00,  6.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.31it/s]
#                    all        152        236       0.77      0.614       0.65      0.326
#
# 40 epochs completed in 0.089 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 42.2MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 42.2MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:02<00:00,  2.47it/s]
#                    all        152        236      0.771      0.614       0.65      0.325
# Results saved to runs/train/exp

# %% [markdown]
# flowers-fruits-garden-strawberry-plant-species.jpg <<이거 정상 이쁜 딸기인데 기존모델은 a1이라고 탐지하는 모습. 2차모델 쓰면 탐지 안됨

# %%
# !python detect.py --weights /content/best.pt --img 640 --source /content/sample
# Out:
# detect: weights=['/content/best.pt'], source=/content/sample, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46151358 parameters, 0 gradients, 107.8 GFLOPs
# image 1/3 /content/sample/19825_m_1.jpg: 480x640 2 a1_strawberrys, 39.2ms
# image 2/3 /content/sample/ash.jpg: 416x640 1 a1_strawberry, 39.9ms
# image 3/3 /content/sample/flowers-fruits-garden-strawberry-plant-species.jpg: 416x640 2 a1_strawberrys, 9.7ms
# Speed: 0.4ms pre-process, 29.6ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --source /content/sample
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/sample, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# image 1/3 /content/sample/19825_m_1.jpg: 480x640 (no detections), 40.2ms
# image 2/3 /content/sample/ash.jpg: 416x640 2 a1_strawberrys, 39.3ms
# image 3/3 /content/sample/flowers-fruits-garden-strawberry-plant-species.jpg: 416x640 (no detections), 7.4ms
# Speed: 0.4ms pre-process, 29.0ms inference, 0.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --source /content/sample
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/sample, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# image 1/13 /content/sample/1128871_20211209_1_1_a1_1_2_13_2_3.jpg: 640x640 1 a1_strawberry, 7.1ms
# image 2/13 /content/sample/1128872_20211209_1_1_a1_1_2_13_2_4.jpg: 640x640 1 a1_strawberry, 7.2ms
# image 3/13 /content/sample/1128873_20211209_1_1_a1_1_2_13_2_5.jpg: 640x640 1 a1_strawberry, 7.3ms
# image 4/13 /content/sample/1128874_20211209_1_1_a1_1_2_13_2_6.jpg: 640x640 1 a1_strawberry, 9.4ms
# image 5/13 /content/sample/1128875_20211209_1_1_a1_1_2_13_2_7.jpg: 640x640 1 a1_strawberry, 7.3ms
# image 6/13 /content/sample/1128876_20211209_1_1_a1_1_2_13_2_8.jpg: 640x640 1 a1_strawberry, 7.2ms
# image 7/13 /content/sample/1128877_20211209_1_1_a1_1_2_13_2_9.jpg: 640x640 2 a1_strawberrys, 7.3ms
# image 8/13 /content/sample/1128878_20211209_1_1_a1_1_2_13_2_10.jpg: 640x640 1 a1_strawberry, 7.3ms
# image 9/13 /content/sample/1128879_20211209_1_1_a1_1_2_13_2_11.jpg: 640x640 1 a1_strawberry, 7.8ms
# image 10/13 /content/sample/1128880_20211209_1_1_a1_1_2_13_2_12.jpg: 640x640 1 a1_strawberry, 7.2ms
# image 11/13 /content/sample/19825_m_1.jpg: 480x640 (no detections), 39.6ms
# image 12/13 /content/sample/ash.jpg: 416x640 2 a1_strawberrys, 40.2ms
# image 13/13 /content/sample/flowers-fruits-garden-strawberry-plant-species.jpg: 416x640 (no detections), 6.8ms
# Speed: 0.6ms pre-process, 12.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6

# %%
# !zip -r /content/yolov5/runs/train/exp.zip /content/yolov5/runs/train/exp

# %%
from google.colab import files
files.download("/content/yolov5/runs/train/exp.zip")
