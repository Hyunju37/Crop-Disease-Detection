# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xP6hx51zkcF0mpjcZ3ca")
project = rf.workspace("capstone-qhqkt").project("cucumber-final")
dataset = project.version(1).download("yolov5")

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16088, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 16088 (delta 10), reused 14 (delta 2), pack-reused 16056
# Receiving objects: 100% (16088/16088), 14.72 MiB | 8.50 MiB/s, done.
# Resolving deltas: 100% (11042/11042), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !python detect.py --weights /content/drive/MyDrive/Capstone/model/cucumber/epoch50.pt --conf-thres=0.1 --img 640 --source /content/sample

# %%
# !python train.py --img 640 --batch 32 --epochs 40 --data "Cucumber-Final-1/data.yaml" --weights yolov5l.pt --cache ram
# Out:
# 2023-12-06 21:14:01.120170: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-06 21:14:01.120224: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-06 21:14:01.120254: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --conf-thres=0.1 --img 640 --source /content/sample-d
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/sample-d, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46151358 parameters, 0 gradients, 107.8 GFLOPs
# image 1/78 /content/sample-d/downy--0.jpg: 640x480 4 a3_cucumbers, 1 a4_cucumber, 87.3ms
# image 2/78 /content/sample-d/downy--10.jpg: 640x448 1 a3_cucumber, 88.6ms
# image 3/78 /content/sample-d/downy--11.jpg: 384x640 1 a3_cucumber, 87.8ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --conf-thres=0.1 --img 640 --source /content/sample-p
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/sample-p, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46151358 parameters, 0 gradients, 107.8 GFLOPs
# image 1/83 /content/sample-p/powdery--0.jpg: 512x640 20 a4_cucumbers, 88.1ms
# image 2/83 /content/sample-p/powdery--1.jpg: 352x640 16 a4_cucumbers, 89.5ms
# image 3/83 /content/sample-p/powdery--10.jpg: 512x640 17 a4_cucumbers, 10.7ms
# ...

# %%
# !zip -r /content/yolov5/runs/train/exp2.zip /content/yolov5/runs/train/exp2

# %%
from google.colab import files
files.download("/content/yolov5/runs/train/exp2.zip")
