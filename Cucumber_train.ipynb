# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xP6hx51zkcF0mpjcZ3ca")
project = rf.workspace("capstone-qhqkt").project("cucumber-znek1")
dataset = project.version(2).download("yolov5")

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
import os
import json
import random
from pathlib import Path
from PIL import Image
from shutil import copy2

# %%
import torch
torch.cuda.device_count()
torch.cuda.empty_cache()

# %%
# !python train.py --img 640 --batch 64 --epochs 50 --data "Cucumber-2/data.yaml" --weights yolov5l.pt --cache ram
# Out:
# 2023-11-24 00:07:15.789717: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 00:07:15.789775: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 00:07:15.789805: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5l.pt, cfg=, data=Cucumber-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 82.4MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5l.pt to yolov5l.pt...
# 100% 89.3M/89.3M [00:00<00:00, 476MB/s]
#
# Overriding model.yaml nc=80 with nc=9
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     75390  models.yolo.Detect                      [9, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model summary: 368 layers, 46181374 parameters, 46181374 gradients, 108.4 GFLOPs
#
# Transferred 607/613 items from yolov5l.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 101 weight(decay=0.0), 104 weight(decay=0.0005), 104 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov5/Cucumber-2/train/labels... 7725 images, 0 backgrounds, 0 corrupt: 100% 7725/7725 [00:01<00:00, 6475.18it/s]
# train: New cache created: /content/yolov5/Cucumber-2/train/labels.cache
# train: Caching images (8.8GB ram): 100% 7725/7725 [00:06<00:00, 1160.34it/s]
# val: Scanning /content/yolov5/Cucumber-2/valid/labels... 1546 images, 0 backgrounds, 0 corrupt: 100% 1546/1546 [00:00<00:00, 3259.31it/s]
# val: New cache created: /content/yolov5/Cucumber-2/valid/labels.cache
# val: Caching images (1.8GB ram): 100% 1546/1546 [00:02<00:00, 677.97it/s]
#
# AutoAnchor: 1.85 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/exp
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/49      35.6G    0.04537    0.02139     0.0408        125        640: 100% 121/121 [01:04<00:00,  1.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:13<00:00,  1.01s/it]
#                    all       1546       1546      0.901      0.263      0.375      0.265
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/49      35.4G    0.03314    0.01162    0.02695        125        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.14it/s]
#                    all       1546       1546       0.33      0.355      0.399      0.285
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/49      35.4G    0.02821    0.01027    0.02017        116        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.487      0.536      0.517      0.342
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/49      35.4G    0.02478    0.01043    0.01728        122        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.16it/s]
#                    all       1546       1546      0.404      0.475       0.41      0.305
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/49      35.4G    0.02207    0.01028    0.01829        124        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.15it/s]
#                    all       1546       1546      0.647      0.749      0.732      0.579
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/49      35.4G    0.02198   0.009724    0.01659        119        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.613      0.699      0.739        0.6
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/49      35.4G    0.02538    0.00985    0.01636        118        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.736      0.861      0.819      0.672
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/49      35.4G    0.01913   0.009426    0.01307        117        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.788      0.903      0.862      0.729
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/49      35.4G    0.01857    0.00883    0.01284        115        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.774      0.869      0.854      0.734
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/49      35.4G    0.02028   0.008863    0.01417        131        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.14it/s]
#                    all       1546       1546      0.762      0.894      0.878      0.781
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/49      35.4G    0.01971   0.008591    0.01343        126        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.14it/s]
#                    all       1546       1546      0.802       0.85      0.877      0.755
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/49      35.4G    0.01866   0.008539    0.01138        123        640: 100% 121/121 [00:58<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.749      0.848      0.837      0.753
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/49      35.4G    0.01831   0.008264     0.0116        135        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.811      0.857      0.862      0.783
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/49      35.4G     0.0169    0.00816    0.01152        129        640: 100% 121/121 [00:58<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.742      0.846      0.858      0.779
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/49      35.4G    0.01835   0.008277    0.01092        119        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.818      0.907      0.885      0.805
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/49      35.4G    0.01633   0.007855    0.01015        113        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.784       0.85      0.846      0.775
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/49      35.4G    0.01545   0.007876    0.01013        113        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.844      0.838      0.825      0.757
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/49      35.4G    0.01392   0.007708    0.00951        123        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.763      0.895       0.87      0.799
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/49      35.4G    0.01631   0.007675     0.0093        143        640: 100% 121/121 [00:58<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.808      0.878      0.871      0.813
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/49      35.4G    0.01837   0.007691   0.008529        124        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.817      0.874       0.89      0.819
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/49      35.4G    0.01729   0.007723    0.01097        141        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.10it/s]
#                    all       1546       1546      0.838        0.9      0.883      0.836
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/49      35.4G    0.01733   0.007744    0.01074        133        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.838      0.909        0.9      0.849
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/49      35.4G     0.0153   0.007542   0.008374        110        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.787      0.853       0.86      0.802
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/49      35.4G    0.01471   0.007379   0.009627        120        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.761      0.837      0.853      0.793
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/49      35.4G    0.01435   0.007259   0.007519        134        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.826      0.918       0.88      0.834
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/49      35.4G    0.01578   0.007251   0.007896        118        640: 100% 121/121 [00:58<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.887      0.926      0.936      0.898
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/49      35.4G    0.01448    0.00724   0.009764        107        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.871      0.932      0.934      0.884
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/49      35.4G      0.014   0.007091   0.006876        115        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.876      0.908      0.922      0.869
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/49      35.4G    0.01366   0.007016   0.008233        128        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.859      0.921      0.926      0.889
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/49      35.4G    0.01399   0.007049   0.008153        130        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.853      0.861      0.884      0.844
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/49      35.4G    0.01319   0.006896    0.00726        120        640: 100% 121/121 [00:58<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.885      0.942      0.945      0.904
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/49      35.4G    0.01175   0.006968   0.007522        117        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.856      0.944      0.919      0.893
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/49      35.4G    0.01237   0.006841   0.006797        132        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546       0.89      0.932      0.923      0.888
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/49      35.4G    0.01309   0.006817   0.007384        124        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.904       0.94      0.955      0.923
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/49      35.4G    0.01318   0.006777   0.005587        132        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.13it/s]
#                    all       1546       1546      0.913      0.886      0.933        0.9
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/49      35.4G    0.01198   0.006657   0.006851        126        640: 100% 121/121 [00:58<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.858      0.903      0.913      0.887
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/49      35.4G    0.01171   0.006645   0.008034        127        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.856      0.933      0.898      0.874
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/49      35.4G    0.01406   0.006529   0.007478        127        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.829      0.905       0.88      0.854
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/49      35.4G    0.01159   0.006483   0.006053        125        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.887      0.928      0.926      0.903
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/49      35.4G    0.01162   0.006432   0.006261        125        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.887      0.926      0.929      0.907
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/49      35.4G    0.01069   0.006428   0.005943        130        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.902      0.899      0.924      0.901
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/49      35.4G    0.01145   0.006374   0.005153        119        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.11it/s]
#                    all       1546       1546      0.887      0.942       0.93      0.912
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/49      35.4G    0.01149   0.006266   0.006708        126        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546        0.9      0.932      0.925      0.906
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/49      35.4G    0.01152   0.006204   0.005215        125        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.885      0.914      0.926      0.907
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/49      35.4G    0.01022   0.006119   0.004806        126        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.903       0.92      0.932      0.913
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/49      35.4G    0.01177   0.006146   0.006089        132        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.09it/s]
#                    all       1546       1546       0.92      0.918      0.937       0.92
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/49      35.4G   0.009957    0.00603    0.00461        132        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546      0.932      0.916      0.935      0.917
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/49      35.4G   0.009756   0.006024   0.005119        119        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546       0.91      0.931      0.935      0.921
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/49      35.4G   0.009408   0.006014   0.005177        127        640: 100% 121/121 [00:58<00:00,  2.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546        0.9      0.928      0.925       0.91
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/49      35.4G   0.009025   0.005922   0.004221        122        640: 100% 121/121 [00:58<00:00,  2.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:11<00:00,  1.12it/s]
#                    all       1546       1546        0.9      0.914      0.924       0.91
#
# 50 epochs completed in 0.994 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 92.9MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 92.9MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 267 layers, 46151358 parameters, 0 gradients, 107.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:13<00:00,  1.06s/it]
#                    all       1546       1546      0.903       0.94      0.955      0.923
#            00_cucumber       1546        510      0.994      0.997      0.995       0.98
#            a3_cucumber       1546        195      0.992          1      0.995      0.946
#            a4_cucumber       1546        278      0.983      0.989      0.994      0.961
#            b1_cucumber       1546         60          1       0.99      0.995      0.935
#            b6_cucumber       1546        112      0.966      0.756      0.942      0.916
#            b7_cucumber       1546        107      0.443      0.991      0.847      0.821
#            b8_cucumber       1546        105      0.788      0.745      0.836      0.797
#            c3_cucumber       1546        102      0.981          1      0.995      0.968
#            c4_cucumber       1546         77      0.976      0.987      0.995      0.986
# Results saved to runs/train/exp

# %%
# !zip -r /content/yolov5/runs/train/exp.zip /content/yolov5/runs/train/exp

# %%
from google.colab import files
files.download("/content/yolov5/runs/train/exp.zip")

# %%
# !python detect.py --weights /content/best.pt --img 640 --source /content/test_image1
