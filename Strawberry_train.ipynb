# %%
# !pip install Roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="xP6hx51zkcF0mpjcZ3ca")
project = rf.workspace("capstone-qhqkt").project("strawberry-rbo1c")
dataset = project.version(8).download("yolov5")

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16078, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 16078 (delta 6), reused 9 (delta 1), pack-reused 16056
# Receiving objects: 100% (16078/16078), 14.72 MiB | 18.75 MiB/s, done.
# Resolving deltas: 100% (11038/11038), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.8/645.8 kB 37.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# ...

# %%
import torch
torch.cuda.device_count()
# Out:
# 1

# %%
import os
import json
import random
from pathlib import Path
from PIL import Image
from shutil import copy2

# %%
pwd
# Out:
# '/content/yolov5'

# %%
torch.cuda.empty_cache()

# %%
# !python train.py --img 640 --batch 64 --epochs 50 --data "Strawberry-8/data.yaml" --weights yolov5l.pt --cache ram
# Out:
# 2023-11-23 18:32:01.777317: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-23 18:32:01.777379: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-23 18:32:01.777407: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !zip -r /content/yolov5/runs/train/exp.zip /content/yolov5/runs/train/exp

# %%
from google.colab import files
files.download("/content/yolov5/runs/train/exp.zip")

# %%
!7z x '/content/drive-download-20231123T221520Z-001.zip' -o'/content/test_image1'

# %%
#기존모델
# !python detect.py --weights /content/best.pt --img 640 --source /content/test_image

# %%
# !python detect.py --weights /content/best.pt --img 640 --source /content/test_image1
# Out:
# detect: weights=['/content/best.pt'], source=/content/test_image1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46151358 parameters, 0 gradients, 107.8 GFLOPs
# image 1/20 /content/test_image1/432125_20211006_1_2_b6_3_2_12_1_0.jpg: 640x480 1 b6_strawberry, 89.4ms
# image 2/20 /content/test_image1/432126_20211006_1_2_b6_3_2_12_1_1.jpg: 640x480 1 b6_strawberry, 10.9ms
# image 3/20 /content/test_image1/432127_20211006_1_2_b6_3_2_12_1_2.jpg: 640x480 1 b6_strawberry, 10.6ms
# ...

# %%
# !python detect.py --weights /content/best.pt --img 640 --source /content/test_image
# Out:
# detect: weights=['/content/best.pt'], source=/content/test_image, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46151358 parameters, 0 gradients, 107.8 GFLOPs
# image 1/100 /content/test_image/363402_20210915_1_0_0_3_2_11_0_0.jpg: 480x640 1 00_strawberry, 88.2ms
# image 2/100 /content/test_image/363403_20210915_1_0_0_3_2_11_0_1.jpg: 480x640 2 00_strawberrys, 10.4ms
# image 3/100 /content/test_image/363404_20210915_1_0_0_3_2_11_0_2.jpg: 480x640 1 00_strawberry, 10.4ms
# ...

# %%
# !python val.py --data "/content/yolov5/Strawberry-7/data.yaml" --weights "/content/best.pt" --img 640

# %%
# !python val.py --data "/content/yolov5/Strawberry-7/data.yaml" --weights "/content/original_best.pt" --img 640
