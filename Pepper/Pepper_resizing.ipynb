# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
import os

def resize_images(input_dir,output_dir,resize_ratio=0.5):
  for filename in os.listdir(input_dir):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
      input_path = os.path.join(input_dir, filename)
      output_path = os.path.join(output_dir, filename)
      # Open the image
      with Image.open(input_path) as img:
          # Calculate new dimensions based on the resize ratio
          width, height = img.size
          new_width = int(width * resize_ratio)
          new_height = int(height * resize_ratio)

          # Resize the image in place
          resized_img = img.resize((new_width, new_height))

          # Save the resized image, overwriting the original
          resized_img.save(output_path)

# %%
resize_images("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/원천데이터/IMG_고추/고추_병해/병해",
              "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/원천데이터/IMG_고추/고추_병해/resized_병해")
resize_images("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/원천데이터/IMG_고추/고추_생리장해/생리장해",
              "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/원천데이터/IMG_고추/고추_생리장해/resized_생리장해")
resize_images("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/원천데이터/IMG_고추/고추_작물보호제처리반응/작물보호제처리반응",
              "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/원천데이터/IMG_고추/고추_작물보호제처리반응/resized_작물보호제처리반응")

# %%
import json
#bounding box 좌표도 바꿔야함
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/papper_ibm_annotations_a.json",'r') as f:
  original_a_annot = json.load(f)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/papper_ibm_annotations_b.json",'r') as f:
  original_b_annot = json.load(f)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/papper_ibm_annotations_c.json",'r') as f:
  original_c_annot = json.load(f)

# %%
for i in original_a_annot["annotations"]:
  original_a_annot["annotations"][i][0]["x"] = int(original_a_annot["annotations"][i][0]["x"] * 0.5)
  original_a_annot["annotations"][i][0]["y"] = int(original_a_annot["annotations"][i][0]["y"] * 0.5)
  original_a_annot["annotations"][i][0]["x2"] = int(original_a_annot["annotations"][i][0]["x2"] * 0.5)
  original_a_annot["annotations"][i][0]["y2"] = int(original_a_annot["annotations"][i][0]["y2"] * 0.5)

output_file_path = "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/papper_resized_annotations_a.json"
with open(output_file_path,"w") as output_json_file:
  json.dump(original_a_annot,output_json_file,ensure_ascii=False)

for i in original_b_annot["annotations"]:
  original_b_annot["annotations"][i][0]["x"] = int(original_b_annot["annotations"][i][0]["x"] * 0.5)
  original_b_annot["annotations"][i][0]["y"] = int(original_b_annot["annotations"][i][0]["y"] * 0.5)
  original_b_annot["annotations"][i][0]["x2"] = int(original_b_annot["annotations"][i][0]["x2"] * 0.5)
  original_b_annot["annotations"][i][0]["y2"] = int(original_b_annot["annotations"][i][0]["y2"] * 0.5)

output_file_path = "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/papper_resized_annotations_b.json"
with open(output_file_path,"w") as output_json_file:
  json.dump(original_b_annot,output_json_file,ensure_ascii=False)

for i in original_c_annot["annotations"]:
  original_c_annot["annotations"][i][0]["x"] = int(original_c_annot["annotations"][i][0]["x"] * 0.5)
  original_c_annot["annotations"][i][0]["y"] = int(original_c_annot["annotations"][i][0]["y"] * 0.5)
  original_c_annot["annotations"][i][0]["x2"] = int(original_c_annot["annotations"][i][0]["x2"] * 0.5)
  original_c_annot["annotations"][i][0]["y2"] = int(original_c_annot["annotations"][i][0]["y2"] * 0.5)

output_file_path = "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/papper_resized_annotations_c.json"
with open(output_file_path,"w") as output_json_file:
  json.dump(original_c_annot,output_json_file,ensure_ascii=False)

# %%
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/train_pepper_a7_list.txt",'r') as file:
  content = file.read()
  train_pepper_a7 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/train_pepper_a8_list.txt",'r') as file:
  content = file.read()
  train_pepper_a8 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/train_pepper_b3_list.txt",'r') as file:
  content = file.read()
  train_pepper_b3 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/train_pepper_b6_list.txt",'r') as file:
  content = file.read()
  train_pepper_b6 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/train_pepper_b7_list.txt",'r') as file:
  content = file.read()
  train_pepper_b7 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/train_pepper_b8_list.txt",'r') as file:
  content = file.read()
  train_pepper_b8 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/train_pepper_c7_list.txt",'r') as file:
  content = file.read()
  train_pepper_c7 = eval(content)

# %%
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/valid_pepper_a7_list.txt",'r') as file:
  content = file.read()
  valid_pepper_a7 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/valid_pepper_a8_list.txt",'r') as file:
  content = file.read()
  valid_pepper_a8 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/valid_pepper_b3_list.txt",'r') as file:
  content = file.read()
  valid_pepper_b3 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/valid_pepper_b6_list.txt",'r') as file:
  content = file.read()
  valid_pepper_b6 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/valid_pepper_b7_list.txt",'r') as file:
  content = file.read()
  valid_pepper_b7 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/valid_pepper_b8_list.txt",'r') as file:
  content = file.read()
  valid_pepper_b8 = eval(content)
with open("/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/valid_pepper_c7_list.txt",'r') as file:
  content = file.read()
  valid_pepper_c7 = eval(content)

# %%
#print("NM",len(train_pepper_nm),len(valid_pepper_nm))
print("A7",len(train_pepper_a7),len(valid_pepper_a7))
print("A8",len(train_pepper_a8),len(valid_pepper_a8))
print("B3",len(train_pepper_b3),len(valid_pepper_b3))
print("B6",len(train_pepper_b6),len(valid_pepper_b6))
print("B7",len(train_pepper_b7),len(valid_pepper_b7))
print("B8",len(train_pepper_b8),len(valid_pepper_b8))
print("C7",len(train_pepper_c7),len(valid_pepper_c7))
# Out:
# A7 223 271
# A8 975 244
# B3 953 239
# B6 431 108
# B7 428 108
# B8 323 81
# C7 180 46

# %%
# !pip install Roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="2nxKEUjSzlIMWDl3hWnV")
print(rf.workspace())
# Out:
# loading Roboflow workspace...
# {
#   "name": "Capstone",
#   "url": "capstone-qhqkt",
#   "projects": [
#     "capstone-qhqkt/cucumber-znek1",
#     "capstone-qhqkt/hard-hat-sample-dn68r",
#     "capstone-qhqkt/pepper-ldesi",
#     "capstone-qhqkt/strawberry-rbo1c",
#     "capstone-qhqkt/tomato-3ap6q"
#   ]
# }

# %%
project = rf.workspace().project("pepper-ldesi")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
train_pepper_a7 = train_pepper_a7[860:]

# %%
len(train_pepper_a7)
# Out:
# 223

# %%
uploaded_b3s = []
for page in project.search_all(in_dataset=True,fields=["id","created","name","labels"],class_name = "b3_pepper"):
  uploaded_b3s.extend(page)

# %%
len(uploaded_b3s)
# Out:
# 614

# %%
uploaded_b3_files = []
for u in uploaded_b3s:
  uploaded_b3_files.append(u["name"])

# %%
uploaded_b3_files

# %%
valid_pepper_b3

# %%
###얘들은 이미지가 너무 커서 직접 resizing 해야함
############병해
#dir_name_a = "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/papper_resized_annotations_a.json"
#img_dir_a = "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/원천데이터/IMG_고추/고추_병해/resized_병해"
#for img in train_pepper_a7:
#  img_path = os.path.join(img_dir_a,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_a,split='train')
#  except:
#    print('error')

#for img in valid_pepper_a7:
#  img_path = os.path.join(img_dir_a,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_a,split='valid')
#  except:
#    print('error')

#for img in train_pepper_a8:
#  img_path = os.path.join(img_dir_a,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_a,split='train')
#  except:
#    print('error')

#for img in valid_pepper_a8:
#  img_path = os.path.join(img_dir_a,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_a,split='valid')
#  except:
#    print('error')


############생리장해
#b3 트레이닝도 다 올라간 건 아닌데
dir_name_b = "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/papper_resized_annotations_b.json"
img_dir_b = "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/원천데이터/IMG_고추/고추_생리장해/resized_생리장해"
#for img in train_pepper_b3:
#  img_path = os.path.join(img_dir_b,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_b,split='train')
#  except:
#    print('error')
for img in valid_pepper_b3:
  img_path = os.path.join(img_dir_b,img+'.jpg')
  if img+'.jpg' not in uploaded_b3_files:
    try:
      project.upload(img_path,dir_name_b,split='valid')
    except:
      print('error')
#for img in train_pepper_b6:
#  img_path = os.path.join(img_dir_b,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_b,split='train')
#  except:
#    print('error')
#for img in valid_pepper_b6:
#  img_path = os.path.join(img_dir_b,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_b,split='valid')
#  except:
#    print('error')
#for img in train_pepper_b7:
#  img_path = os.path.join(img_dir_b,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_b,split='train')
#  except:
#    print('error')
#for img in valid_pepper_b7:
#  img_path = os.path.join(img_dir_b,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_b,split='valid')
#  except:
#    print('error')
#for img in train_pepper_b8:
#  img_path = os.path.join(img_dir_b,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_b,split='train')
#  except:
#    print('error')
#for img in valid_pepper_b8:
#  img_path = os.path.join(img_dir_b,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_b,split='valid')
#  except:
#    print('error')

############처리반응
#dir_name_c = "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/라벨링데이터/VL1_고추/papper_resized_annotations_c.json"
#img_dir_c = "/content/drive/MyDrive/Capstone/AIHUB-dataset/104.식물 병 유발 통합 데이터/01.데이터/2.Validation/원천데이터/IMG_고추/고추_작물보호제처리반응/resized_작물보호제처리반응"
#for img in train_pepper_c7:
#  img_path = os.path.join(img_dir_c,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_c,split='train')
#  except:
#    print('error')
#for img in valid_pepper_c7:
#  img_path = os.path.join(img_dir_c,img+'.jpg')
#  try:
#    project.upload(img_path,dir_name_c,split='valid')
#  except:
#    print('error')
