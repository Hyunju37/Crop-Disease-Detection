# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xP6hx51zkcF0mpjcZ3ca")
project = rf.workspace("capstone-qhqkt").project("pepper-final-ndlhk")
dataset = project.version(1).download("yolov5")

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16088, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 16088 (delta 10), reused 14 (delta 2), pack-reused 16056
# Receiving objects: 100% (16088/16088), 14.72 MiB | 19.94 MiB/s, done.
# Resolving deltas: 100% (11042/11042), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
import os
import json
import random
from pathlib import Path
from PIL import Image
from shutil import copy2

# %%
import torch
print(torch.cuda.device_count())
torch.cuda.empty_cache()
# Out:
# 1

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data "Pepper-Final-1/data.yaml" --weights yolov5l.pt --cache ram
# Out:
# 2023-12-07 16:00:51.047871: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-07 16:00:51.047929: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-07 16:00:51.047958: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !zip -r /content/yolov5/runs/train/exp2.zip /content/yolov5/runs/train/exp2

# %%
from google.colab import files
files.download("/content/yolov5/runs/train/exp2.zip")

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --source /content/sample-p
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/sample-p, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46145973 parameters, 0 gradients, 107.8 GFLOPs
# image 1/40 /content/sample-p/powdery--16.jpg: 512x640 1 a7_pepper, 1 a8_pepper, 42.2ms
# image 2/40 /content/sample-p/powdery--18.jpg: 352x640 1 a8_pepper, 42.2ms
# image 3/40 /content/sample-p/powdery--21.jpg: 640x320 1 a8_pepper, 42.5ms
# ...
