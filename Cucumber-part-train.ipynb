# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xP6hx51zkcF0mpjcZ3ca")
project = rf.workspace("capstone-qhqkt").project("cucumber-parts")
dataset = project.version(1).download("yolov5")

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
import os
import json
import random
from pathlib import Path
from PIL import Image
from shutil import copy2

# %%
import torch
torch.cuda.device_count()
torch.cuda.empty_cache()

# %%
# !python train.py --img 640 --batch 16 --epochs 40 --data "Cucumber-parts-1/data.yaml" --weights yolov5m.pt --cache ram

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --conf-thres=0.1 --img 640 --source /content/sample
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/sample, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# image 1/10 /content/sample/white1.jpg: 512x640 (no detections), 44.7ms
# image 2/10 /content/sample/white10.jpg: 416x640 1 a4_cucumber, 44.8ms
# image 3/10 /content/sample/white2.jpg: 480x640 (no detections), 45.9ms
# image 4/10 /content/sample/white3.jpg: 512x640 20 a4_cucumbers, 11.6ms
# ...

# %%
# !zip -r /content/yolov5/runs/train/exp.zip /content/yolov5/runs/train/exp2

# %%
from google.colab import files
files.download("/content/yolov5/runs/train/exp.zip")
