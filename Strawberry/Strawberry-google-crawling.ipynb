# %%
pip install git+https://github.com/Joeclinton1/google-images-download.git
# Out:
# Collecting git+https://github.com/Joeclinton1/google-images-download.git
#   Cloning https://github.com/Joeclinton1/google-images-download.git to /tmp/pip-req-build-x9xivb8t
#   Running command git clone --filter=blob:none --quiet https://github.com/Joeclinton1/google-images-download.git /tmp/pip-req-build-x9xivb8t
#   Resolved https://github.com/Joeclinton1/google-images-download.git to commit e91e6a38ad654877f59edc7894822f5319d75df1
#   Preparing metadata (setup.py) ... done
# Collecting selenium (from google-images-download==2.8.0)
#   Downloading selenium-4.15.2-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 57.3 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium->google-images-download==2.8.0) (2.0.7)
# Collecting trio~=0.17 (from selenium->google-images-download==2.8.0)
#   Downloading trio-0.23.1-py3-none-any.whl (448 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.3/448.3 kB 30.3 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium->google-images-download==2.8.0)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium->google-images-download==2.8.0) (2023.11.17)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->google-images-download==2.8.0) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->google-images-download==2.8.0) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->google-images-download==2.8.0) (3.6)
# Collecting outcome (from trio~=0.17->selenium->google-images-download==2.8.0)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->google-images-download==2.8.0) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->google-images-download==2.8.0) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium->google-images-download==2.8.0)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium->google-images-download==2.8.0) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium->google-images-download==2.8.0)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.7 MB/s eta 0:00:00
# Building wheels for collected packages: google-images-download
#   Building wheel for google-images-download (setup.py) ... done
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=15950 sha256=49f469b83f055920f42a6ebc5634dc968471545e4bffd684f1b2c15d1b144921
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1bupjpm0/wheels/82/e1/ab/4e3bcfefbfbcdb0c84035e1099e8ced83edbf28448601fe0c2
# Successfully built google-images-download
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium, google-images-download
# Successfully installed google-images-download-2.8.0 h11-0.14.0 outcome-1.3.0.post0 selenium-4.15.2 trio-0.23.1 trio-websocket-0.11.1 wsproto-1.2.0

# %%
arguments

# %%
#importing the library
from google_images_download import google_images_download

#class instantiation
response = google_images_download.googleimagesdownload()

# keywords : 원하는 검색 키워드
# limit : 원하는 다운로드 사진 개수 (수정 버전에서는 최대 100개까지 가능)
# format : 다운로드 확장자 지정
arguments = {"keywords":"딸기 흰가루병, strawberry powdery mildew",
            "limit":100,
            "print_urls":True,
            "format":"jpg"
            }

#passing the arguments to the function
paths = response.download(arguments = arguments)

#printing absolute paths of the downloaded images
print(paths)
