# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xP6hx51zkcF0mpjcZ3ca")
project = rf.workspace("object-detection-ws").project("strawberrydetection")
dataset = project.version(1).download("yolov5")

# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
import os
import json

# %%
with open('/content/strawberry_a2_universe_scrap.txt','r') as file:
  content = file.read()

# %%
soup = BeautifulSoup(content,'html.parser')

# %%
imgs = []
paragraphs = soup.find_all('p')
for p in paragraphs:
  imgs.append(p.text)

# %%
imgs.sort()

# %%
len(imgs)
# Out:
# 92

# %%
imgs

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="2nxKEUjSzlIMWDl3hWnV")
print(rf.workspace())
# Out:
# loading Roboflow workspace...
# {
#   "name": "Capstone",
#   "url": "capstone-qhqkt",
#   "projects": [
#     "capstone-qhqkt/cucumber-parts",
#     "capstone-qhqkt/cucumber-znek1",
#     "capstone-qhqkt/hard-hat-sample-dn68r",
#     "capstone-qhqkt/pepper-ldesi",
#     "capstone-qhqkt/pepper-parts",
#     "capstone-qhqkt/strawberry-parts-d9fnc",
#     "capstone-qhqkt/strawberry-rbo1c",
#     "capstone-qhqkt/tomato-3ap6q",
#     "capstone-qhqkt/tomato-parts"
#   ]
# }

# %%
train_img_dir = '/content/StrawBerryDetection-1/train/images'
test_img_dir = '/content/StrawBerryDetection-1/test/images'
valid_img_dir = '/content/StrawBerryDetection-1/valid/images'

train_imgs = os.listdir(train_img_dir)
test_imgs = os.listdir(test_img_dir)
valid_imgs = os.listdir(valid_img_dir)

# %%
print(len(train_imgs)+len(test_imgs)+len(valid_imgs))
# Out:
# 880

# %%
s = '1_000024_jpg.rf.e019dd194d62c42145bb7b109aeaaa57.jpg'
s.split('.')[0]
# Out:
# '1_000024_jpg'

# %%
img_set = set(imgs)

# %%
len(img_set)
# Out:
# 115

# %%
cnt_a = 0
for i in train_imgs:
  i = i.split('.')[0]
  if (i.rsplit('_', 1)[0] + '.' + i.rsplit('_', 1)[1]) in imgs:
    cnt_a += 1
'''cnt_b = 0
for i in test_imgs:
  i = i.split('.')[0]
  if (i.rsplit('_', 1)[0] + '.' + i.rsplit('_', 1)[1]) in imgs:
    cnt_b += 1
cnt_c = 0
for i in valid_imgs:
  i = i.split('.')[0]
  if (i.rsplit('_', 1)[0] + '.' + i.rsplit('_', 1)[1]) in imgs:
    cnt_c += 1'''
print(cnt_a)
# Out:
# 105

# %%
project = rf.workspace().project("strawberry-parts-d9fnc")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
for j in train_imgs:
  fn = j.split('.')[0]
  if fn.rsplit('_', 1)[0] + '.' + fn.rsplit('_', 1)[1] in imgs:
    img_path = os.path.join('/content/StrawBerryDetection-1/train/images',j)
    project.upload(img_path)
