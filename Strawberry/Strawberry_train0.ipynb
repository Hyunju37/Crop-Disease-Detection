# %%
'''!pip install Roboflow'''

# %%
'''!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xP6hx51zkcF0mpjcZ3ca")
project = rf.workspace("capstone-qhqkt").project("strawberry-final")
dataset = project.version(1).download("yolov5")
'''

# %%
# !unzip /content/drive/MyDrive/Capstone/FINAL-dataset/Strawberry-Final.v1i.yolov5pytorch.zip -d /content/Strawberry

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16088, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 16088 (delta 10), reused 14 (delta 2), pack-reused 16056
# Receiving objects: 100% (16088/16088), 14.71 MiB | 18.73 MiB/s, done.
# Resolving deltas: 100% (11038/11038), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
import torch
torch.cuda.device_count()
# Out:
# 1

# %%
import os
import json
import random
from pathlib import Path
from PIL import Image
from shutil import copy2

# %%
pwd
# Out:
# '/content/yolov5'

# %%
# !python train.py --img 640 --batch 16 --epochs 40 --data "Strawberry-parts-4/data.yaml" --weights yolov5m.pt --cache ram

# %%
# !python train.py --img 640 --batch 32 --epochs 40 --data "Strawberry-parts-4/data.yaml" --weights yolov5m.pt --cache ram

# %%
pwd
# Out:
# '/content/yolov5'

# %%
# !python train.py --img 640 --batch 32 --epochs 40 --data "Strawberry/data.yaml" --weights yolov5l.pt --cache ram
# Out:
# 2023-12-06 19:04:51.931618: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-06 19:04:51.931675: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-06 19:04:51.931722: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/Capstone/model/strawberry/epoch50.pt --conf-thres=0.1 --img 640 --source /content/sample

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --conf-thres=0.25 --img 640 --source /content/sample

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --conf-thres=0.25 --img 640 --source /content/sample

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --conf-thres=0.25 --img 640 --source /content/sample-normal

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --conf-thres=0.25 --img 640 --source /content/sample-normal

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --conf-thres=0.25 --img 640 --source /content/sample1

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --conf-thres=0.2 --img 640 --source /content/sample

# %%
# !python detect.py --weights /content/drive/MyDrive/Capstone/model/strawberry/strawberry-final-best.pt --conf-thres=0.2 --img 640 --source /content/sample-p

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --conf-thres=0.2 --img 640 --source /content/sample-p

# %%
# !zip -r /content/yolov5/runs/train/exp2.zip /content/yolov5/runs/train/exp2

# %%
from google.colab import files
files.download("/content/yolov5/runs/train/exp2.zip")

# %%
# !python detect.py --weights /content/drive/MyDrive/Capstone/model/strawberry/strawberry-final-best-large.pt --conf-thres=0.1 --img 640 --source /content/sam
# Out:
# detect: weights=['/content/drive/MyDrive/Capstone/model/strawberry/strawberry-final-best-large.pt'], source=/content/sam, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CPU
#
# Fusing layers...
# Model summary: 267 layers, 46151358 parameters, 0 gradients, 107.8 GFLOPs
# image 1/151 /content/sam/greymold--1.jpg: 480x640 7 a1_strawberrys, 2 a2_strawberrys, 386.5ms
# image 2/151 /content/sam/greymold--10.jpg: 448x640 3 a1_strawberrys, 355.3ms
# image 3/151 /content/sam/greymold--11.jpg: 448x640 2 a1_strawberrys, 328.7ms
# ...

# %%
print(len(os.listdir("/content/drive/MyDrive/Capstone/FINAL-dataset/Strawberry-Final-1/train/labels")))
