# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16083, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 16083 (delta 7), reused 9 (delta 1), pack-reused 16056
# Receiving objects: 100% (16083/16083), 14.65 MiB | 13.01 MiB/s, done.
# Resolving deltas: 100% (11039/11039), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
pwd
# Out:
# '/content/yolov5'

# %%
# !python detect.py --weights /content/drive/MyDrive/Capstone/model/strawberry/epoch50.pt --conf-thres 0.1 --img 640 --source /content/google_sample

# %%
# !python detect.py --weights /content/drive/MyDrive/Capstone/model/strawberry/strawberry-a1-part.pt --conf-thres 0.25 --img 640 --source /content/sample

# %%
# !python detect.py --weights /content/drive/MyDrive/Capstone/model/strawberry/best.pt --conf-thres 0.1 --img 640 --source /content/powder_sample
# Out:
# detect: weights=['/content/drive/MyDrive/Capstone/model/strawberry/best.pt'], source=/content/powder_sample, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CPU
#
# Fusing layers...
# Model summary: 212 layers, 20856975 parameters, 0 gradients, 47.9 GFLOPs
# image 1/3 /content/powder_sample/powder0.jpg: 416x640 1 a1_strawberry, 676.0ms
# image 2/3 /content/powder_sample/powder1.jpg: 448x640 (no detections), 700.5ms
# image 3/3 /content/powder_sample/powder2.jpg: 480x640 1 a1_strawberry, 848.4ms
# ...
